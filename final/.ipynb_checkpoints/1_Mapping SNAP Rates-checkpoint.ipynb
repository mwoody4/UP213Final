# %% [markdown]
# # SNAP Gap in Los Angeles County: Spatial Patterns and Predictors
# #### Meaghan Woody

# %% [markdown]
# ### Part 1: Mapping SNAP Rate and SNAP Gap (AIM 1)
#
# **1. Map the distribution of SNAP gap and food insecurity in Los Angeles County in varying geographic units.**

# %% [markdown]
# The observed SNAP participation rate was calculated as percentage of all households receiving SNAP divided by total households >150% FPL.
#
# The SNAP Gap, also defined as SNAP-Eligible But Not Enrolled (EBNE), was calculated as households >100% FPL not enrolled in SNAP divided by the total households >150% FPL. The ACS variable “households >100% FPL not enrolled in SNAP” is the only available proxy for SNAP non-enrollment provided by ACS. This is a conservative proxy for the percentage of eligible but not enrolled (EBNE) households by census tract, because, in California, households can make less than or equal to 130% of the federal poverty level and still qualify for the SNAP program. However, under California's modified categorical eligibility standard, eligibility can go up to 200% of FPL. The 150% cut-off was chosen as a estimate. This is a limitation as it likely overestimates the SNAP gap.

# %%
# Load in the files for mapping

import geopandas as gpd

# Tract-level
snap_tracts = gpd.read_file("/Users/markwoody/Desktop/UP 213/UP213Final/final/data/snap_tracts_exp.gpkg")

# ZIP-code level
snap_zcta = gpd.read_file("/Users/markwoody/Desktop/UP 213/UP213Final/final/data/snap_zcta_exp.gpkg")

# %%
# Check for missing values
snap_tracts['snap_ebne'].isna().sum() 
snap_tracts['snap_rate'].isna().sum()

# 30 tracts have missing values. This is a marginal proportion and should not mess up any calculation.
# Out:
# 30

# %% [markdown]
# Check the raw proportions of SNAP gap and SNAP enrollment using box plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style for better aesthetics
sns.set(style="whitegrid")

# Create the boxplot for SNAP Rates and SNAP Gap
plt.figure(figsize=(8, 6))
sns.boxplot(data=snap_tracts[['snap_rate', 'snap_ebne']], palette="pastel")
plt.title('Distribution of SNAP Rate vs. SNAP Gap', fontsize=14, weight='bold')
plt.ylabel('Rate (%)', fontsize=12)
plt.xticks([0, 1], ['SNAP Rate', 'SNAP Gap'], fontsize=11)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Mean and standard deviatiion
table = snap_tracts[['snap_rate', 'snap_ebne']].agg(['mean', 'std'])
print(table)
# Out:
#       snap_rate  snap_ebne
# mean  21.289411  17.320289
# std   13.223573  11.906589

# %% [markdown]
# SNAP Rate mean is 21.29% with a standard deviation of 17.32%. This is much lower than expected due to methodological limitations. As described earlier, the denominator includes households up to 150% FPL, many of which could be ineligible for SNAP under standard 130% FPL rules, unless they have individual cases. Second, ACS survey data undercounts actual SNAP participation due to benefit underreporting and mismatches between annual (ACS) and monthly (SNAP) eligibility windows.
#
# The SNAP Gap mean is 17.32% with a standard deviation of 11.90%. The SNAP Gap rates in Los Angeles County have not been documented recently and there is no averages to be compared to.
#
# The following maps will map the distribution of SNAP gap and SNAP enrollment. These can highlight areas with low utilization where targeted outreach may be needed.

# %%
## Tract level Maps

import matplotlib.pyplot as plt
import contextily as ctx

# Create side-by-side figure to compare SNAP rate vs SNAP gap
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 10))

# Reproject to Web Mercator
snap_tracts_web = snap_tracts.to_crs('EPSG:3857')

# Map 1 - SNAP rate 
snap_tracts_web.plot(
    column='snap_rate',
    scheme='quantiles',
    k=5,
    cmap='Greens',
    legend=True,
    ax=ax1,
    alpha=1,
    edgecolor='gray',
    legend_kwds={
        'fmt': "{:.1f}",
        'title': "SNAP Rate\n(Quintiles)",
        'loc': 'upper left',
        'bbox_to_anchor': (1.02, 1),
        'borderaxespad': 0
    }
)
ax1.set_title("Observed SNAP Rate (%) in Los Angeles County (ACS 2023)", fontsize=13)
ax1.set_ylim([3.98e6, 4.14e6])
ax1.set_xticks([])
ax1.set_yticks([])
ctx.add_basemap(ax1, zoom=10, source=ctx.providers.OpenStreetMap.Mapnik)

# Map 2 - SNAP gap
snap_tracts_web.plot(
    column='snap_ebne',
    scheme='quantiles',
    k=5,
    cmap='Oranges',
    legend=True,
    ax=ax2,
    alpha=1,
    edgecolor='gray',
    legend_kwds={
        'fmt': "{:.1f}",
        'title': "SNAP Gap (EBNE)\n(Quintiles)",
        'loc': 'upper left',
        'bbox_to_anchor': (1.02, 1),
        'borderaxespad': 0
    }
)
ax2.set_title("SNAP Gap (%) in Los Angeles County (ACS 2023)", fontsize=13)
ax2.set_ylim([3.98e6, 4.14e6])
ax2.set_xticks([])
ax2.set_yticks([])
ctx.add_basemap(ax2, zoom=10, source=ctx.providers.OpenStreetMap.Mapnik)

plt.tight_layout()
plt.show()

# %% [markdown]
# As suspected, tracts might be too small of a unit to assess what is going on in terms of SNAP gap and SNAP rate. One interesting thing to note is how West LA is showing higher SNAP gap, even though it is typically a higher income area. Central and South Central LA appears to have higher SNAP rate participation and lower SNAP gap. South LA has a higher SNAP Gap.

# %% [markdown]
# ### Part 2. Spatial Clusters (AIM 2)
#
# **2. Conduct a cluster analysis using SNAP gap and SNAP participation rates**
#
# Since the census tracts are small and numerous (over 2,410 tracts), it might be helpful to group them into broader categories that reflect similar SNAP-related outcomes.
#
# The following method applies k-means clustering to observed SNAP participation and SNAP gap rates to identify tract clusterings, such as high participation and low gap, or low participation and high gap. Mapping these clusters may helps visualize where different SNAP profiles are concentrated across the county and may be meaningful to see if there are any spatial clusters in the SNAP participation and SNAP gap showing aggregagted areas of need of participation.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Look at two features of SNAP (snap gap and snap rate) 
features = ['snap_ebne', 'snap_rate']
df_cluster = snap_tracts[features].dropna()

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_cluster)

# Use KMeans function for clustering
kmeans = KMeans(n_clusters=5, random_state=1)
cluster_labels = kmeans.fit_predict(X_scaled)

# Assign cluster labels to df
snap_tracts.loc[df_cluster.index, 'cluster_id'] = cluster_labels

# %%
# Cluster analysis map

fig, ax = plt.subplots(figsize=(10, 10))
snap_tracts.to_crs('EPSG:3857').plot(
    column='cluster_id',
    categorical=True,
    legend=True,
    cmap='tab20',
    ax=ax,
    alpha=0.7,
    edgecolor='black',
)
ax.set_ylim([3.98e6, 4.14e6])
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
ax.set_title("Cluster Analysis of SNAP Features by Los Angeles County Tracts (ACS 2023)", fontsize=14)
ax.set_xticks([])
ax.set_yticks([])
plt.tight_layout()
plt.show()

# %%
# Summary table of snap rate and snap gap per each cluster
snap_tracts.groupby('cluster_id')[['snap_rate', 'snap_ebne']].mean().round(1)
# Out:
#             snap_rate  snap_ebne
# cluster_id
# 0                13.5       23.6
# 1                32.5       14.3
# 2                16.6        9.3
# 3                14.8       44.8
# 4                60.3       21.5
# 5                 NaN        NaN
# 6                 NaN        NaN
# 8                 NaN        NaN
# 9                 NaN        NaN
# 10                NaN        NaN
# 11                NaN        NaN
# 13                NaN        NaN
# 14                NaN        NaN
# 15                NaN        NaN
# 17                NaN        NaN
# 18                NaN        NaN

# %% [markdown]
# Only clusters 0 to 4 had enough data to present on the map. Cluster 0 showed low SNAP usage but moderate SNAP gap, spread out all over the county but especially in the Antellope Valley. Cluster 1 showed higher SNAP usage, and low gap, likely better-served areas. Cluster 2 showed moderate usage, very low gap, centered in South LA. Cluster 3 had the highest SNAP Gap, which were only a few sites across the county in the far north, far west, and far south. Cluster 4 had the highest SNAP usage rate, which are only a few random areas across the county.
#
# This analysis helps reveal that areas with similar SNAP gap and SNAP participation are not always geographically clustered, which shows that targeted outreach should be based on need rather than location. Identifying feature clusters of tracts can inform more tailored outreach strategies to reduce the SNAP gap.

# %% [markdown]
# ### Part 3. Aggregate to Service Planning Areas (AIM 1)
#
# SNAP outreach may not be meaningful at the tract-level and producing results at the SPA-level might be better for a quick snapshot to see what is happening across the county. Service planning areas (SPAs) are distinct geographic regions used by the Los Angeles Department of Public Health to develop and provide more relevant and targeted outreach to the specific health needs of the residents in these different areas.
#
# Downloaded Los Angeles County Service Planning Areas (SPAs) 2022 from https://egis-lacounty.hub.arcgis.com/datasets/lacounty::service-planning-areas-2022-view/about
#
# The same mapping procedures for SNAP rate and SNAP gap are repeated for the SPA-level.

# %%
# Load in the SPA boundaries
spas = gpd.read_file('/Users/markwoody/Desktop/UP 213/UP213Final/final/data/Service_Planning_Areas_2022_view_8558881845522833049.zip')
spas = spas.to_crs(epsg=4326)
spas.head(8) # There are 8 SPAs
# Out:
#   SPA         SPA_NAME ABBV  LABEL  SPA_NUM  \
# 0   1  Antelope Valley  ATV  SPA 1        1
# 1   2     San Fernando  SFV  SPA 2        2
# 2   3      San Gabriel  SGV  SPA 3        3
# 3   4            Metro  MET  SPA 4        4
# 4   5             West    W  SPA 5        5
# 5   6            South    S  SPA 6        6
# 6   7             East    E  SPA 7        7
# 7   8        South Bay  SBA  SPA 8        8
#
#                                             geometry
# 0  POLYGON ((-117.65523 34.39722, -117.65524 34.3...
# 1  POLYGON ((-118.7659 34.75362, -118.77967 34.75...
# 2  POLYGON ((-117.97228 34.43878, -117.9723 34.43...
# 3  POLYGON ((-118.30434 34.15884, -118.30283 34.1...
# 4  POLYGON ((-118.94469 34.045, -118.94463 34.045...
# 5  POLYGON ((-118.34542 34.03996, -118.34471 34.0...
# 6  MULTIPOLYGON (((-118.1741 33.81892, -118.17414...
# 7  POLYGON ((-118.17414 33.81892, -118.1741 33.81...

# %%
# Left join ACS data with SPA boundaries
tracts_spa = gpd.sjoin(snap_tracts, spas, how='left', predicate='within')
tracts_spa.head(2)
# Out:
#          GEOID B05002_021E B05002_013E B01001_002E B01001_026E B01001_020E  \
# 0  06037101110         347        1608        2035        2117         101
# 1  06037101122         347        2122        2130        2068          49
#
#   B01001_021E B01001_022E B01001_023E B01001_024E  ... median_income  \
# 0         120          55          50          63  ...       84091.0
# 1          66         149          54          32  ...       99583.0
#
#   avg_hh_size                                           geometry cluster_id  \
# 0        2.60  MULTIPOLYGON (((-118.30229 34.2587, -118.30091...        4.0
# 1        2.98  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...        1.0
#
#   index_right SPA      SPA_NAME ABBV  LABEL SPA_NUM
# 0         1.0   2  San Fernando  SFV  SPA 2     2.0
# 1         1.0   2  San Fernando  SFV  SPA 2     2.0
#
# [2 rows x 73 columns]

# %%
# Aggregate ACS tract data up to SPAs. Only the SNAP rates and SNAP gap are needed for mapping
cols = ['snap_rate', 'snap_ebne']
spa_aggregated = tracts_spa.groupby('SPA')[cols].mean().reset_index()
spa_aggregated.head(8)
# Out:
#   SPA  snap_rate  snap_ebne
# 0   1  22.955604  11.752398
# 1   2  22.802202  17.534819
# 2   3  18.496464  16.034030
# 3   4  23.352959  20.023803
# 4   5  18.386770  28.132028
# 5   6  22.977673  10.695379
# 6   7  21.156264  12.797156

# %%
# Merge with SPA geometries
snap_spa = spas.merge(spa_aggregated, on='SPA')
snap_spa.head(8)
# Out:
#   SPA         SPA_NAME ABBV  LABEL  SPA_NUM  \
# 0   1  Antelope Valley  ATV  SPA 1        1
# 1   2     San Fernando  SFV  SPA 2        2
# 2   3      San Gabriel  SGV  SPA 3        3
# 3   4            Metro  MET  SPA 4        4
# 4   5             West    W  SPA 5        5
# 5   6            South    S  SPA 6        6
# 6   7             East    E  SPA 7        7
#
#                                             geometry  snap_rate  snap_ebne
# 0  POLYGON ((-117.65523 34.39722, -117.65524 34.3...  22.955604  11.752398
# 1  POLYGON ((-118.7659 34.75362, -118.77967 34.75...  22.802202  17.534819
# 2  POLYGON ((-117.97228 34.43878, -117.9723 34.43...  18.496464  16.034030
# 3  POLYGON ((-118.30434 34.15884, -118.30283 34.1...  23.352959  20.023803
# 4  POLYGON ((-118.94469 34.045, -118.94463 34.045...  18.386770  28.132028
# 5  POLYGON ((-118.34542 34.03996, -118.34471 34.0...  22.977673  10.695379
# 6  MULTIPOLYGON (((-118.1741 33.81892, -118.17414...  21.156264  12.797156

# %% [markdown]
# It looks like SPA 8 (South Bay) is missing from the aggregation. It's possible that no census tracts matched its boundary during the spatial join due to boundary alignment issues in the shapefile. Thiis is limitation that SPA-level analyses do not include data for South Bay.

# %%
import matplotlib.pyplot as plt
import contextily as ctx

# Reproject
spa_web = snap_spa.to_crs('EPSG:3857')

# Side-by-side figure
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 10))

# Map 1 - SNAP rate 
spa_web.plot(
    column='snap_rate',
    scheme='quantiles',
    k=5,
    cmap='Greens',
    legend=True,
    ax=ax1,
    edgecolor='gray',
    alpha=1,
    legend_kwds={
        'fmt': "{:.1f}",
        'title': "Observed SNAP Rate\n(Quintiles)",
        'loc': 'upper left',
        'bbox_to_anchor': (1.02, 1),
        'borderaxespad': 0
    }
)
ax1.set_title('SPA-level Observed SNAP Rate (%) in Los Angeles County (ACS 2023)', fontsize=13)
ax1.set_ylim([3.98e6, 4.14e6])
ax1.set_xticks([])
ax1.set_yticks([])
ctx.add_basemap(ax1, zoom=10, source=ctx.providers.OpenStreetMap.Mapnik)

# Map 2 - SNAP gap 
spa_web.plot(
    column='snap_ebne',
    scheme='quantiles',
    k=5,
    cmap='Oranges',
    legend=True,
    ax=ax2,
    edgecolor='gray',
    alpha=1,
    legend_kwds={
        'fmt': "{:.1f}",
        'title': "SNAP Gap\n(Quintiles)",
        'loc': 'upper left',
        'bbox_to_anchor': (1.02, 1),
        'borderaxespad': 0
    }
)
ax2.set_title('SPA-level SNAP Gap (%) in Los Angeles County (ACS 2023)', fontsize=13)
ax2.set_ylim([3.98e6, 4.14e6])
ax2.set_xticks([])
ax2.set_yticks([])
ctx.add_basemap(ax2, zoom=10, source=ctx.providers.OpenStreetMap.Mapnik)

# Show the name of each SPA in grey font
for idx, row in spa_web.iterrows():
    centroid = row['geometry'].centroid
    ax1.text(centroid.x, centroid.y, str(row['SPA_NAME']), fontsize=10, ha='center', weight='bold', color='#666666')
    ax2.text(centroid.x, centroid.y, str(row['SPA_NAME']), fontsize=10, ha='center', weight='bold', color='#666666')

plt.tight_layout()
plt.show()

# %% [markdown]
# Create bar chart to show SNAP participation and SNAP gap by SPA-level. This is another visualization for presentation.

# %%
import numpy as np

# Create summary table
summary_table = snap_spa[['SPA_NAME', 'snap_rate', 'snap_ebne']].groupby('SPA_NAME').mean()

summary_table = summary_table.rename(columns={
    'snap_rate': 'Avg SNAP Rate (%)',
    'snap_ebne': 'Avg SNAP Gap (%)'
})

# Sort by SNAP rate (highest to lowest)
summary_table = summary_table.sort_values('Avg SNAP Rate (%)', ascending=False)
summary_table = summary_table.round(1)

# Create a bar chart to visualize SNAP averages by SPAs
spa_names = summary_table.index 
fig, ax = plt.subplots(figsize=(10, 8))  # unpack fig and ax correctly
width = 0.35  # Width of each bar
y = np.arange(len(spa_names)) 

bars1 = ax.barh(y - width/2, summary_table['Avg SNAP Rate (%)'], width, 
                label='SNAP Rate', color='green')       # green
bars2 = ax.barh(y + width/2, summary_table['Avg SNAP Gap (%)'], width, 
                label='SNAP Gap', color='#cc5500')  # orange

ax.set_title('SNAP Participation vs SNAP Gap Rates (%) by SPA in Los Angeles County, ACS 2023', pad=20, fontsize=14)
ax.set_xlabel('Rate (%)', labelpad=10)
ax.set_yticks(y)
ax.set_yticklabels(spa_names)
ax.legend(loc='lower right', frameon=False)

# Add labels
for bar in bars1 + bars2:
    bar_width = bar.get_width()
    ax.text(bar_width + 0.5,  
            bar.get_y() + bar.get_height()/2,
            f'{bar_width:.1f}%',
            va='center',
            fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# After aggregating to the SPA level, it appears that Metro and South SPAs show the highest SNAP participation rates, yet also the highest SNAP gap rates, suggesting that although enrollment is concentrated, there remains substantial unmet need. South and Antelope Valley also show high participation with relatively low gaps, which may reflect more effective outreach or eligibility alignment in those areas.
#
# The West showed the lowest SNAP participation and highest gap, suggesting an area for targeted outreach. It is interesting to see that the West has a large unmet need, which could be due to a large proprtion of individuals living just above the 130% FPL threshold, who may still face food insecurity but remain ineligible for federal assistance.

# %% [markdown]
# ### Part 4. Statistics on Food Insecurity (AIM 1)
#
# In order to get the full picture of where outreach is needed for CalFresh, it is necessary to understand the spatial disparities of food insecurity in Los Angeles County. City- and SPA-level food insecurity rates are analyzed to provide additional context to SNAP participation and enrollment gaps. Although tract-level food insecurity data are not available through the American Community Survey and therefore cannot be used in the machine learning analysis in Aim 3, this are still useful to illustrate how the SNAP gap may contribute to food insecurity.
#
# SPA-level reports on food insecurity. Downloaded data from Los Angeles City Geohub: https://geohub.lacity.org/datasets/9ecfeddddb9e4630aa10c92b0daeea6c_0/explore?location=33.771520%2C-118.353165%2C8.16
#
# Population in Households with Food Insecurity by each city. Data provided by Los Angeles County Department of Public Health (DPH) for the Community Health Profiles (CHP) Data Initiative: https://geohub.lacity.org/datasets/9b5c7a6b308f4091813d0e6e64e852c7_0/explore?location=33.871267%2C-118.342846%2C8.43
#
# The unit of measurement is described as such: "Data for cities, communities, and City of Los Angeles Council Districts were generated using a small area estimation method which combined the survey data with population benchmark data (2022 population estimates for Los Angeles County) and neighborhood characteristics data (e.g., U.S. Census Bureau, 2017-2021 American Community Survey 5-Year Estimates). Households experiencing food insecurity are defined as those with low food security or very low food security in the last 12 months. Food insecurity is assessed by a scaled variable created from a series of five questions."
#
# The same mapping procedures for food insecurity are repeated for the city- and SPA-level.

# %%
# Load in SPA-level food insecurity data

spa_fi = gpd.read_file('/Users/markwoody/Desktop/UP 213/UP213Final/final/data/SPA_and_food_insecurity.zip')
print(spa_fi.columns)
spa_fi.head(2)

# Remove the % format on Food_Insec column and convert to float
spa_fi['FI'] = spa_fi['Food_Insec'].str.replace('%', '').astype(float)
spa_fi.head(2)
# Out:
# Index(['OBJECTID_1', 'OBJECTID', 'SPA_NAME', 'LABEL', 'ABBV', 'SPA_2012',
#        'Join_Count', 'SPA_Number', 'Median_Inc', 'Index_', 'SPA', 'Food_Secur',
#        'Food_Insec', 'geometry'],
#       dtype='object')
#    OBJECTID_1  OBJECTID SPA_NAME LABEL   ABBV  SPA_2012  Join_Count  \
# 0           1         6    South     S  SPA 6         6           1
# 1           2         4    Metro   MET  SPA 4         4           1
#
#    SPA_Number  Median_Inc  Index_    SPA Food_Secur Food_Insec  \
# 0           6       36400       6  SPA 6        11%        16%
# 1           4       47173       4  SPA 4        13%        17%
#
#                                             geometry    FI
# 0  POLYGON ((-13174153 4034170, -13174075 4034151...  16.0
# 1  POLYGON ((-13169580 4050151, -13168967 4049995...  17.0

# %%
# Load in the city-level food insecurity data

city_fi = gpd.read_file('/Users/markwoody/Desktop/UP 213/UP213Final/final/data/Population_with_Food_Insecurity_3358006855397152269.zip')
print(city_fi.columns)
city_fi.head(2)
# Out:
# Index(['Geo_ID', 'Geo_Type', 'Geo_Name', 'POP_FI', 'POP_FI_LCL', 'POP_FI_UCL',
#        'POP_FI_RSE', 'POP_FI_EST', 'geometry'],
#       dtype='object')
#                   Geo_ID           Geo_Type              Geo_Name  POP_FI  \
# 0  csa_city_agoura_hills  Incorporated City  City of Agoura Hills     0.0
# 1      csa_city_alhambra  Incorporated City      City of Alhambra    21.1
#
#    POP_FI_LCL  POP_FI_UCL  POP_FI_RSE           POP_FI_EST  \
# 0         0.0         0.0         0.0                 None
# 1        19.0        23.2         5.1  small area estimate
#
#                                             geometry
# 0  POLYGON ((6341261 1884292.5, 6341258 1884280, ...
# 1  POLYGON ((6525011 1860749.875, 6525931.5 18612...

# %% [markdown]
# ### SPA-level food insecurity rates
#
# Repeat same mapping procedures for the city-level data.

# %%
# SPA-level map

# Reproject
spafi_web = spa_fi.to_crs('EPSG:3857')

# Side-by-side figure
fig4, ax = plt.subplots(figsize=(16,10))

spa_fi.to_crs('EPSG:3857').plot(
    column='FI',
        ax=ax,
        markersize=20,  # Consistent size
        cmap='Blues',
        legend=True,
        scheme='quantiles',  # Use quantile classification
        k=5,    
        )

# drop Catalina
ax.set_ylim([3.98e6, 4.14e6])

# add a basemap
ctx.add_basemap(ax=ax, zoom=10, source=ctx.providers.OpenStreetMap.Mapnik)

# drop the tick labels
ax.set_xticks([])
ax.set_yticks([])

# add a title
ax.set_title('Food Insecurity by SPAs in Los Angeles County, 2021: Source: LA City Geohub')

# Show the name of each SPA in grey font
for idx, row in spafi_web.iterrows():
    centroid = row['geometry'].centroid
    ax.text(centroid.x, centroid.y, str(row['SPA_NAME']), fontsize=10,
            ha='center', weight='bold', color='#666666')

plt.tight_layout()
plt.show()

# %% [markdown]
# Note that the South Bay label has fallen down the map and is staying in the white area.

# %%
# Create summary table for FI
fi_summary = spa_fi[['SPA_NAME', 'FI']].groupby('SPA_NAME').mean()

# Rename and format
fi_summary = fi_summary.rename(columns={'FI': 'Food Insecurity Rate (%)'})
fi_summary = fi_summary.round(1)

# Sort highest to lowest
fi_summary = fi_summary.sort_values('Food Insecurity Rate (%)', ascending=False)

# Pull FI rates
spa_names = fi_summary.index
rates = fi_summary['Food Insecurity Rate (%)']

# Create plot
fig5, ax = plt.subplots(figsize=(10, 6))
y = np.arange(len(spa_names))

bars = ax.barh(y, rates, color='#87CEEB') 

# Labels and titles
ax.set_title('Food Insecurity by SPAs in Los Angeles County, 2021: Source: LA City Geohub', pad=20, fontsize=14)
ax.set_xlabel('Food Insecurity Rate (%)', labelpad=10)
ax.set_yticks(y)
ax.set_yticklabels(spa_names)

# Add data labels to bars
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.5, bar.get_y() + bar.get_height()/2, f'{width:.1f}%', va='center', fontsize=9)

plt.tight_layout()

# %% [markdown]
# Overall, the burden of food insecurity is highest in East, San Gabriel, Metro, and South. South LA and Metro, which show the highest levels of food insecurity, also showed high SNAP participation.
#
# West LA shows relatively lower food insecurity rates yet had the highest SNAP gap and lowest SNAP participation. This could indicate barriers to enrollment or limited outreach in a region where eligible households remain underserved. By overlaying these patterns, the map reinforces that while SNAP is being used in high-need areas, significant disparities remain—especially in places like the West.

# %% [markdown]
# ### City-level food insecurity rates
#
# Repeat same mapping procedures for the city-level data.

# %%
# City-level food insecurity map 
fig6, ax = plt.subplots(figsize=(16,10))

city_fi.to_crs('EPSG:3857').plot(
    column='POP_FI',
        ax=ax,
        markersize=20,  # Consistent size
        cmap='Blues',
        legend=True,
        edgecolor='gray',
        legend_kwds={'label': "Food Insecurity (%)",
        'shrink': 0.5,  # make the color bar shorter
        'aspect': 20} # controls width — higher = skinnier                         
                     )

# drop Catalina
ax.set_ylim([3.98e6, 4.14e6])

# add a basemap
ctx.add_basemap(ax=ax, zoom=10, source=ctx.providers.OpenStreetMap.Mapnik)

# drop the tick labels
ax.set_xticks([])
ax.set_yticks([])

# add a title
ax.set_title('Food Insecurity by Cities in Los Angeles County, 2021: Source: LA City Geohub')
# Out:
# Text(0.5, 1.0, 'Food Insecurity by Cities in Los Angeles County, 2021: Source: LA City Geohub')

# %%
# Clean city entries
city_fi_clean = city_fi[
    (city_fi['POP_FI'] > 0) &               # zero population level
    (city_fi['Geo_Name'].notna()) &         #NAs
    (city_fi['Geo_Name'].str.strip() != '') # blank
]

# Sort cities by FI rate
city_fi_sorted = city_fi_clean.sort_values('POP_FI', ascending=True)

# Pull city names and FI rates
city_names = city_fi_sorted['Geo_Name'].str.strip()
rates = city_fi_sorted['POP_FI']

# Create plot
fig6, ax = plt.subplots(figsize=(10, len(city_names) * 0.35))

y = np.arange(len(city_names))
bars = ax.barh(y, rates, color='#8EAADB')

# Titles
ax.set_title('Food Insecurity by Cities in Los Angeles County, 2021, Source: LA City Geohub', pad=20, fontsize=14)
ax.set_xlabel('Food Insecurity Rate (%)', labelpad=10)
ax.set_yticks(y)
ax.set_ylim([-0.5, len(y) - 0.5])  # remove white spaces at top and bottom
ax.set_yticklabels(city_names)

# Data labels
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.5, bar.get_y() + bar.get_height()/2, f'{width:.1f}%', va='center', fontsize=8)

plt.tight_layout()

# %% [markdown]
# It is interesting to see that a few cities in the Antelope Valley report high food insecurity despite the area's overall high SNAP participation and low SNAP gap at the SPA level. This suggests that SPA-level averages may obscure within-region disparities and reinforced how different geographic levels can be used for different circumstances. Additionally, the City of Los Angeles reports high food insecurity, which is why it is meaningful to separate it by SPA to understand the local population, as the City of Los Angeles spans multiple regions with distinct socioeconomic profiles.
#
# Several cities within the Metro and South SPAs also show elevated food insecurity, aligning with observed needs in those areas. However, some cities with high SNAP gap and low participation—such as parts of the West SPA—do not report correspondingly high food insecurity, which may reflect underreporting, differences in population eligibility, or other structural barriers to assistance.
#
# It’s important to note that the food insecurity data are from 2021, while SNAP-related measures come from the 2023 ACS. Despite this limitation, these maps still provide meaningful insights into persistent areas of unmet need and can help inform geographically targeted outreach strategies.
